# %%
import numpy as np
import pandas as pd
from transformers import BertForSequenceClassification, BertTokenizer
import torch
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from sklearn.metrics import f1_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
# Load the pre-trained BERT model and tokenizer
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=1) # Change num_labels to 1 for regression
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Load the CSV file
data = pd.read_csv(r"C:/Users/me1awq/PhD/docsim/datasets/open_source/sick.csv")
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Split the data into train, validation, and test sets
train_data, val_data, test_data = np.split(data.sample(frac=1, random_state=42), [int(.6*len(data)), int(.8*len(data))])

# Tokenize the texts
train_encodings = tokenizer(train_data['sentence_A'].tolist(), train_data['sentence_B'].tolist(), truncation=True, padding=True)
val_encodings = tokenizer(val_data['sentence_A'].tolist(), val_data['sentence_B'].tolist(), truncation=True, padding=True)
test_encodings = tokenizer(test_data['sentence_A'].tolist(), test_data['sentence_B'].tolist(), truncation=True, padding=True)

# Convert the tokenized data into PyTorch tensors
train_dataset = TensorDataset(torch.tensor(train_encodings['input_ids']), torch.tensor(train_encodings['attention_mask']), torch.tensor(train_data['relatedness_score'].tolist()))
val_dataset = TensorDataset(torch.tensor(val_encodings['input_ids']), torch.tensor(val_encodings['attention_mask']), torch.tensor(val_data['relatedness_score'].tolist()))
test_dataset = TensorDataset(torch.tensor(test_encodings['input_ids']), torch.tensor(test_encodings['attention_mask']), torch.tensor(test_data['relatedness_score'].tolist()))

# Define the data loader for training, validation, and test
batch_size = 15
train_dataloader = DataLoader(train_dataset, sampler=RandomSampler(train_dataset), batch_size=batch_size)
val_dataloader = DataLoader(val_dataset, sampler=SequentialSampler(val_dataset), batch_size=batch_size)
test_dataloader = DataLoader(test_dataset, sampler=SequentialSampler(test_dataset), batch_size=batch_size)

# Define the optimizer and loss function
optimizer = torch.optim.AdamW(model.parameters(), lr=2e-5, eps=1e-8)
loss_fn = torch.nn.MSELoss()

# Train the model

# %%
# Define the optimizer and loss function
optimizer = torch.optim.AdamW(model.parameters(), lr=2e-5, eps=1e-8)
loss_fn = torch.nn.MSELoss()

# Train the model
epochs = 30
train_losses = []
val_losses = []
test_losses = []
for epoch in range(epochs):
    model.train()
    train_loss = 0
    for batch in train_dataloader:
        input_ids, attention_mask, labels = batch
        optimizer.zero_grad()
        outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss
        train_loss += loss.item()
        loss.backward()
        optimizer.step()

    # Validate the model
    model.eval()
    val_loss = 0
    val_preds = []
    val_labels = []
    for batch in val_dataloader:
        input_ids, attention_mask, labels = batch
        with torch.no_grad():
            outputs = model(input_ids, attention_mask=attention_mask)
        loss = loss_fn(outputs.logits, labels.view(-1,1))
        val_loss += loss.item()
        preds = outputs.logits.view(-1).cpu().numpy()
        val_preds.extend(preds)
        val_labels.extend(labels.cpu().numpy())
    val_mse = mean_squared_error(val_labels, val_preds)

    # Store the losses for plotting
    train_losses.append(train_loss/len(train_dataloader))
    val_losses.append(val_loss/len(val_dataloader))

    print("Epoch {} Train loss: {:.4f} Validation loss: {:.4f} Validation MSE: {:.4f}".format(epoch+1, train_loss/len(train_dataloader), val_loss/len(val_dataloader), val_mse))

    # Test the model
    model.eval()
    test_loss = 0
    test_preds = []
    test_labels = []
    for batch in test_dataloader:
        input_ids, attention_mask, labels = batch
        with torch.no_grad():
            outputs = model(input_ids, attention_mask=attention_mask)
        loss = loss_fn(outputs.logits, labels.view(-1,1))
        test_loss += loss.item()
        preds = outputs.logits.view(-1).cpu().numpy()
        test_preds.extend(preds)
        test_labels.extend(labels.cpu().numpy())

    # Store the losses for plotting
    test_losses.append(test_loss/len(test_dataloader))

    test_mse = mean_squared_error(test_labels, test_preds)
    print("Epoch {} Train loss: {:.4f} Test loss: {:.4f} Test MSE: {:.4f}".format(epoch+1, train_loss/len(train_dataloader), test_loss/len(test_dataloader), test_mse))
# Out:
# Epoch 1 Train loss: 1.2942 Validation loss: 0.4396 Validation MSE: 0.4396
# Epoch 1 Train loss: 1.2942 Test loss: 0.4236 Test MSE: 0.4236
# Epoch 2 Train loss: 0.3499 Validation loss: 0.3140 Validation MSE: 0.3140
# Epoch 2 Train loss: 0.3499 Test loss: 0.2815 Test MSE: 0.2815
# Epoch 3 Train loss: 0.2443 Validation loss: 0.3084 Validation MSE: 0.3084
# Epoch 3 Train loss: 0.2443 Test loss: 0.2819 Test MSE: 0.2819
# Epoch 4 Train loss: 0.1874 Validation loss: 0.2785 Validation MSE: 0.2785
# Epoch 4 Train loss: 0.1874 Test loss: 0.2627 Test MSE: 0.2627
# Epoch 5 Train loss: 0.1537 Validation loss: 0.3137 Validation MSE: 0.3137
# Epoch 5 Train loss: 0.1537 Test loss: 0.2880 Test MSE: 0.2880
# Epoch 6 Train loss: 0.1270 Validation loss: 0.2929 Validation MSE: 0.2929
# Epoch 6 Train loss: 0.1270 Test loss: 0.2730 Test MSE: 0.2730
# Epoch 7 Train loss: 0.1095 Validation loss: 0.2889 Validation MSE: 0.2889
# Epoch 7 Train loss: 0.1095 Test loss: 0.2555 Test MSE: 0.2555
# Epoch 8 Train loss: 0.0950 Validation loss: 0.3216 Validation MSE: 0.3216
# Epoch 8 Train loss: 0.0950 Test loss: 0.2992 Test MSE: 0.2992
# Epoch 9 Train loss: 0.0796 Validation loss: 0.3138 Validation MSE: 0.3138
# Epoch 9 Train loss: 0.0796 Test loss: 0.3051 Test MSE: 0.3051
# Epoch 10 Train loss: 0.0703 Validation loss: 0.3111 Validation MSE: 0.3111
# Epoch 10 Train loss: 0.0703 Test loss: 0.2887 Test MSE: 0.2887
# Epoch 11 Train loss: 0.0667 Validation loss: 0.3614 Validation MSE: 0.3614
# Epoch 11 Train loss: 0.0667 Test loss: 0.3383 Test MSE: 0.3383
# Epoch 12 Train loss: 0.0600 Validation loss: 0.3168 Validation MSE: 0.3168
# Epoch 12 Train loss: 0.0600 Test loss: 0.3133 Test MSE: 0.3133
# Epoch 13 Train loss: 0.0593 Validation loss: 0.3076 Validation MSE: 0.3076
# Epoch 13 Train loss: 0.0593 Test loss: 0.2937 Test MSE: 0.2937
# Epoch 14 Train loss: 0.0489 Validation loss: 0.3031 Validation MSE: 0.3031
# Epoch 14 Train loss: 0.0489 Test loss: 0.2867 Test MSE: 0.2867
# Epoch 15 Train loss: 0.0529 Validation loss: 0.2966 Validation MSE: 0.2966
# Epoch 15 Train loss: 0.0529 Test loss: 0.2936 Test MSE: 0.2936
# Epoch 16 Train loss: 0.0473 Validation loss: 0.2956 Validation MSE: 0.2956
# Epoch 16 Train loss: 0.0473 Test loss: 0.2880 Test MSE: 0.2880
# Epoch 17 Train loss: 0.0449 Validation loss: 0.2787 Validation MSE: 0.2787
# Epoch 17 Train loss: 0.0449 Test loss: 0.2725 Test MSE: 0.2725
# Epoch 18 Train loss: 0.0460 Validation loss: 0.3122 Validation MSE: 0.3122
# Epoch 18 Train loss: 0.0460 Test loss: 0.3002 Test MSE: 0.3002
# Epoch 19 Train loss: 0.0421 Validation loss: 0.2878 Validation MSE: 0.2878
# Epoch 19 Train loss: 0.0421 Test loss: 0.2784 Test MSE: 0.2784
# Epoch 20 Train loss: 0.0404 Validation loss: 0.3028 Validation MSE: 0.3028
# Epoch 20 Train loss: 0.0404 Test loss: 0.2932 Test MSE: 0.2932
# Epoch 21 Train loss: 0.0386 Validation loss: 0.2833 Validation MSE: 0.2833
# Epoch 21 Train loss: 0.0386 Test loss: 0.2825 Test MSE: 0.2825
# Epoch 22 Train loss: 0.0389 Validation loss: 0.2782 Validation MSE: 0.2782
# Epoch 22 Train loss: 0.0389 Test loss: 0.2697 Test MSE: 0.2697
# Epoch 23 Train loss: 0.0370 Validation loss: 0.3362 Validation MSE: 0.3362
# Epoch 23 Train loss: 0.0370 Test loss: 0.3236 Test MSE: 0.3236
# Epoch 24 Train loss: 0.0346 Validation loss: 0.3132 Validation MSE: 0.3132
# Epoch 24 Train loss: 0.0346 Test loss: 0.3034 Test MSE: 0.3034
# Epoch 25 Train loss: 0.0357 Validation loss: 0.2879 Validation MSE: 0.2879
# Epoch 25 Train loss: 0.0357 Test loss: 0.2668 Test MSE: 0.2668
# Epoch 26 Train loss: 0.0346 Validation loss: 0.3337 Validation MSE: 0.3337
# Epoch 26 Train loss: 0.0346 Test loss: 0.3219 Test MSE: 0.3219
# Epoch 27 Train loss: 0.0307 Validation loss: 0.3073 Validation MSE: 0.3073
# Epoch 27 Train loss: 0.0307 Test loss: 0.2919 Test MSE: 0.2919
# Epoch 28 Train loss: 0.0345 Validation loss: 0.3022 Validation MSE: 0.3022
# Epoch 28 Train loss: 0.0345 Test loss: 0.2919 Test MSE: 0.2919
# Epoch 29 Train loss: 0.0338 Validation loss: 0.3004 Validation MSE: 0.3004
# Epoch 29 Train loss: 0.0338 Test loss: 0.2801 Test MSE: 0.2801
# Epoch 30 Train loss: 0.0306 Validation loss: 0.3175 Validation MSE: 0.3175
# Epoch 30 Train loss: 0.0306 Test loss: 0.3113 Test MSE: 0.3113

# %%
# Plot the train, validation, and test losses
plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
# Plot the train, validation, and test losses
plt.plot(train_losses, label="Train Loss")
plt.plot(test_losses, label="Test Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
